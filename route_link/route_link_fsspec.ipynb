# %% [markdown]
# ## FSSPEC download for NWM RouteLink file for developing topologic relationships
# This notebook demonstrates accessing the National Water Model (NWM) topological definition of the NWM channel routing simulation. The methods applied here utilize Zarr and FSSpec to retrieve the header for the file and then only the topology-definining fields: "link" and "to". Building the dataframe directly from these elements in the file from the web saves a 200Mb download and takes quite a bit less time than when obtaining the full file and operating from a local storage resource.
#
# The key here is to note which operations take a long time:
# * The initial `SingleHdf5ToZarr` step is about 1 second
# * The `.translate()` operation (inline in our example) is about 8 seconds
# * Opening the dataset from the translated .json object is only a few milliseconds
# * reading the "to" and "from" attributes into a pandas dataframe is 11 seconds
#
# That last step would be a lot longer if all variables were downloaded.

# %%
# Suppress the output of the pip install for display sanity...
# If there are problems, be sure to uncomment and check the output!
# !pip install fsspec kerchunk zarr xarray[complete]
# Out:
# Requirement already satisfied: fsspec in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (2024.12.0)
# Requirement already satisfied: kerchunk in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (0.2.7)
# Requirement already satisfied: zarr in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (2.18.4)
# Requirement already satisfied: xarray[complete] in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (2025.1.1)
# Requirement already satisfied: numcodecs in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from kerchunk) (0.15.0)
# Requirement already satisfied: numpy in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from kerchunk) (2.1.3)
# Requirement already satisfied: ujson in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from kerchunk) (5.10.0)
# Requirement already satisfied: asciitree in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: fasteners in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from zarr) (0.19)
# Requirement already satisfied: packaging>=23.2 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (24.2)
# Requirement already satisfied: pandas>=2.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (2.2.3)
# Requirement already satisfied: deprecated in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from numcodecs->kerchunk) (1.2.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from pandas>=2.1->xarray[complete]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from pandas>=2.1->xarray[complete]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from pandas>=2.1->xarray[complete]) (2025.1)
# Requirement already satisfied: scipy in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.15.1)
# Requirement already satisfied: bottleneck in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.4.2)
# Requirement already satisfied: numbagg in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.8.2)
# Requirement already satisfied: numba>=0.54 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.61.0)
# Requirement already satisfied: flox in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.10.0)
# Requirement already satisfied: opt_einsum in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (3.4.0)
# Requirement already satisfied: netCDF4 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.7.2)
# Requirement already satisfied: h5netcdf in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.5.0)
# Requirement already satisfied: cftime in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.6.4.post1)
# Requirement already satisfied: pooch in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.8.2)
# Requirement already satisfied: sparse in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.15.5)
# Requirement already satisfied: dask[complete] in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (2025.1.0)
# Requirement already satisfied: cartopy in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.24.1)
# Requirement already satisfied: matplotlib in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (3.10.0)
# Requirement already satisfied: nc-time-axis in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (1.4.1)
# Requirement already satisfied: seaborn in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from xarray[complete]) (0.13.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from numba>=0.54->xarray[complete]) (0.44.0)
# Requirement already satisfied: six>=1.5 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray[complete]) (1.17.0)
# Requirement already satisfied: shapely>=1.8 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from cartopy->xarray[complete]) (2.0.6)
# Requirement already satisfied: pyshp>=2.3 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from cartopy->xarray[complete]) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from cartopy->xarray[complete]) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (4.55.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from matplotlib->xarray[complete]) (3.2.1)
# Requirement already satisfied: click>=8.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (1.0.0)
# Requirement already satisfied: pyarrow>=14.0.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (19.0.0)
# Requirement already satisfied: lz4>=4.3.2 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (4.4.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from deprecated->numcodecs->kerchunk) (1.17.2)
# Requirement already satisfied: numpy_groupies>=0.9.19 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from flox->xarray[complete]) (0.11.2)
# Requirement already satisfied: h5py in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from h5netcdf->xarray[complete]) (3.12.1)
# Requirement already satisfied: certifi in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from netCDF4->xarray[complete]) (2024.12.14)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from pooch->xarray[complete]) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from pooch->xarray[complete]) (2.32.3)
# Requirement already satisfied: locket in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[complete]) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pooch->xarray[complete]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pooch->xarray[complete]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from requests>=2.19.0->pooch->xarray[complete]) (2.3.0)
# Requirement already satisfied: distributed==2025.1.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]->xarray[complete]) (2025.1.0)
# Requirement already satisfied: bokeh>=3.1.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]->xarray[complete]) (3.6.2)
# Requirement already satisfied: jinja2>=2.10.3 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from dask[complete]->xarray[complete]) (3.1.5)
# Requirement already satisfied: msgpack>=1.0.2 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (1.1.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (6.1.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (6.4.2)
# Requirement already satisfied: zict>=3.0.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from distributed==2025.1.0->dask[complete]->xarray[complete]) (3.0.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from bokeh>=3.1.0->dask[complete]->xarray[complete]) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/qylee/nwm_network_lstm_test/.venv/lib/python3.12/site-packages (from jinja2>=2.10.3->dask[complete]->xarray[complete]) (3.0.2)

# %%
import fsspec
import xarray as xr
from kerchunk.hdf import SingleHdf5ToZarr

fs = fsspec.filesystem("http")

rl_nwm_url = "https://www.nco.ncep.noaa.gov/pmb/codes/nwprod/nwm.v3.0.13/parm/domain/RouteLink_CONUS.nc"
with fs.open(rl_nwm_url) as f:
    # %time    rl_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=0).translate()

    # Key example here:
    # https://fsspec.github.io/kerchunk/test_example.html
# Out:
# CPU times: user 55.8 ms, sys: 21.1 ms, total: 76.9 ms
# Wall time: 1.13 s

# %% [markdown]
# The `kerchunk`-ing example that we started with had a number of other parameters...
# perhaps some might be reintroduced to make the data access even speedier!
# e.g., ...
# ```py
# fs = fsspec.filesystem('ftp', host="https://www.nco.ncep.noaa.gov/pmb")
#
# with fs.open(rl_nwm_url, mode='rb', anon=True, default_fill_cache=False, default_cache_type='first') as f:
# ```
#  ...
#
# One thing that I specifically explored was the size of the `inline_threshold` setting. Smaller values definitely provided better results, though not a massivie improvement -- 9 seconds overall vs. 11 or so.
# ```py
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url).translate() # 11.1 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=30000).translate() # 11.3 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=300).translate() # 11.2 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=10).translate() # 11.3 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=2).translate() # 9.8 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=1).translate() # 9.85 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=0).translate() # 9.83 s
#     %time    rl_h5_t = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=-1).translate() # 9.54 s
# ```
# Inlining the `.translate()` call vs. splitting seemed to be about equal, with inlining having the additional advantage of omitting the unused intermediate output.
# ```py
#     %time    rl_h5 = SingleHdf5ToZarr(f, rl_nwm_url, inline_threshold=0)
#     %time    rl_t = rl_h5.translate() # This translate MUST happen inside the context block
# ```

# %%
backend_args = {
    "consolidated": False,
    "storage_options": {
        "fo": rl_t,
        # Adding these options returns a properly dimensioned but otherwise null dataframe
        # "remote_protocol": "https",
        # "remote_options": {'anon':True}
    },
}
# %time ds = xr.open_dataset("reference://", engine="zarr", backend_kwargs=backend_args,)
# Out:
# CPU times: user 1.38 s, sys: 24.5 ms, total: 1.41 s
# Wall time: 241 ms

# %%
ds.lat.shape
# Out:
# (2776734,)

# %%
ds
# Out:
# <xarray.Dataset> Size: 322MB
# Dimensions:            (feature_id: 2776734)
# Coordinates:
#     lat                (feature_id) float32 11MB 46.23 46.21 46.2 ... 45.0 45.0
#     lon                (feature_id) float32 11MB -96.54 -96.53 ... -74.67 -74.55
# Dimensions without coordinates: feature_id
# Data variables: (12/21)
#     BtmWdth            (feature_id) float32 11MB ...
#     ChSlp              (feature_id) float32 11MB ...
#     Kchan              (feature_id) float32 11MB ...
#     Length             (feature_id) float32 11MB ...
#     MusK               (feature_id) float32 11MB ...
#     MusX               (feature_id) float32 11MB ...
#     ...                 ...
#     link               (feature_id) float64 22MB 6.636e+06 ... 1.545e+07
#     n                  (feature_id) float32 11MB ...
#     nCC                (feature_id) float32 11MB ...
#     order              (feature_id) float64 22MB ...
#     time               datetime64[ns] 8B ...
#     to                 (feature_id) float64 22MB 6.636e+06 6.636e+06 ... 0.0 0.0
# Attributes:
#     Convention:        CF-1.6
#     featureType:       timeSeries
#     history:           Created Thu Sep  9 18:11:34 2021
#     processing_notes:  This file was produced Thu Sep  9 16:16:38 2021 by Kev...

# %%
subslice = [
    "link",
    "to",
    "gages",
]
# %time df = ds[subslice].to_dataframe().astype({"link": int, "to": int,})
# Out:
# CPU times: user 904 ms, sys: 362 ms, total: 1.27 s
# Wall time: 17.2 s

# %%
tt = b'       02465000'

# %%
df[df["gages"]==tt]
# Out:
#                 link        to               gages        lat        lon
# feature_id
# 1839848     18229923  18206548  b'       02465000'  33.208752 -87.592606

# %% [markdown]
# ## Create a topology
# With the downloaded Route_Link, we can generate the topology of the CONUS river network

# %%
df = df.set_index("link")
df
# Out:
#                 to               gages        lat        lon
# link
# 6635572    6635570  b'               '  46.228783 -96.540199
# 6635590    6635600  b'               '  46.213486 -96.530647
# 6635598    6635636  b'               '  46.201508 -96.505341
# 6635622    6635620  b'               '  46.200523 -96.615021
# 6635626    6635624  b'               '  46.195522 -96.637161
# ...            ...                 ...        ...        ...
# 15456832  25371895  b'               '  44.979626 -74.654648
# 25371895         0  b'               '  44.996113 -74.648621
# 15448486         0  b'               '  44.994370 -74.504646
# 25293410         0  b'               '  44.998062 -74.673912
# 15450136         0  b'               '  44.995205 -74.547752
#
# [2776734 rows x 4 columns]

# %%
# NOT Used yet...
def build_mask(param_df, mask_file_path, mask_key):
    data_mask = nhd_io.read_mask(
        mask_file_path,
    )

    return param_df.filter(data_mask.iloc[:, [mask_key]], axis=0)

# %%
import nhd_network
from functools import partial


def replace_downstreams(data, downstream_col, terminal_code):
    ds0_mask = data[downstream_col] == terminal_code
    new_data = data.copy()
    new_data.loc[ds0_mask, downstream_col] = ds0_mask.index[ds0_mask]

    # Also set negative any nodes in downstream col not in data.index
    new_data.loc[~data[downstream_col].isin(data.index), downstream_col] *= -1
    return new_data


def organize_independent_networks(connections):
    rconn = nhd_network.reverse_network(connections)
    independent_networks = nhd_network.reachable_network(rconn)
    reaches_bytw = {}
    for tw, net in independent_networks.items():
        path_func = partial(nhd_network.split_at_junction, net)
        reaches_bytw[tw] = nhd_network.dfs_decomposition(net, path_func)

    return independent_networks, reaches_bytw, rconn

# %%
df = df.sort_index()
df = replace_downstreams(df, "to", 0)

# %%
connections = nhd_network.extract_connections(df, "to")

# %%
independent_networks, reaches_bytw, rconn = organize_independent_networks(connections)

# %%
list(rconn.keys())[3000]
# Out:
# 85620

# %%
rconn[list(rconn.keys())[400000]]
# Out:
# [3935264]

# %% [markdown]
# ### So, what?
# At this point we have a couple of objects representing the U.S. stream network (or another country or region, if you snuck a mask or different base route-link file in there!).
# * `connections` is a dictionary of each `link` and the `to` downstream link id. All connections that point
# to a null downstream (i.e., they flow off the map into the ocean or into an interior terminal basin) have
# been massaged so that they point to an id which is the negative of the last valid segment id.
# * `rconn` is the reverse dictionary of connections. Unlike the connections DAG which is strictly
# coalescing, the `rconn` values contain multiple values where junctions split and the value list may
# contain multiple upstream `link` ids for each of the incoming channels to a junction.
# * `independent_networks` is a grouping of the rconn dictionary into connections that are related
# topologically to a single tailwater. THIS IS NOT ORDERED (except by whatever falls out of the original reversal of the connections dictionary.)
# * `reaches_bytw` is perhaps the most mysterious. It is a topologically ordered list of lists for
# each tailwater that, if traversed in order, guarantees that each leaf of the tailwater DAG is touched
# before any downstream junction is traversed.
#
# ### Example:
# We can run simple script to find the networks of any given size. We choose a size of 8 so we can diagram things more easily.

# %%
d = independent_networks
for k in sorted(d, key=lambda k: len(d[k]), reverse=True):
    if len(d[k]) == 8:
        print(k, len(d[k]))
# Out:
# -12058618 8
# -23920468 8
# -11206384 8
# -19856634 8
# -19856494 8
# -10026014 8
# -2161574 8
# -19855962 8
# -19855930 8
# -3340794 8
# -14678498 8
# -19855772 8
# -10680626 8
# -10680610 8
# -3340566 8
# -13891828 8
# -22673446 8
# -20379679 8
# -22673386 8
# -946010074 8
# -14415727 8
# -11335517 8
# -24311527 8
# -10679724 8
# -9500000 8
# -11138376 8
# -9499968 8
# -9499946 8
# -9499940 8
# -17429694 8
# -17495193 8
# -11334709 8
# -10482659 8
# -20640658 8
# -19854180 8
# -2683730 8
# -8188725 8
# -21754632 8
# -19854084 8
# -25227996 8
# -11334313 8
# -9499220 8
# -9499176 8
# -20640206 8
# -10678584 8
# -2683140 8
# -11202810 8
# -10678522 8
# -2683114 8
# -10678500 8
# -9629693 8
# -16052090 8
# -96988956 8
# -9629309 8
# -20311523 8
# -24505642 8
# -20245744 8
# -16051220 8
# -10349490 8
# -20310811 8
# -1174016 8
# -20638204 8
# -11332031 8
# -9496702 8
# -5302245 8
# -7071696 8
# -8316733 8
# -12969788 8
# -11396924 8
# -20571637 8
# -21095547 8
# -17687535 8
# -9888572 8
# -21422878 8
# -20636416 8
# -10674854 8
# -10674802 8
# -22602315 8
# -11854335 8
# -26927610 8
# -10674640 8
# -11854049 8
# -10477663 8
# -20832324 8
# -2547737 8
# -24043297 8
# -24042981 8
# -23059708 8
# -11394300 8
# -1563892 8
# -22142102 8
# -11852777 8
# -940170017 8
# -1170136 8
# -17160812 8
# -23910955 8
# -1169946 8
# -11852025 8
# -11851991 8
# -11851785 8
# -11851659 8
# -10409802 8
# -1693176 8
# -23909563 8
# -1692798 8
# -10736765 8
# -1561634 8
# -2544365 8
# -2544283 8
# -23188055 8
# -11850301 8
# -20828554 8
# -2543877 8
# -2543873 8
# -1691904 8
# -11849853 8
# -20369339 8
# -19058530 8
# -11390774 8
# -11849337 8
# -11849219 8
# -10407334 8
# -21744723 8
# -11324196 8
# -19647094 8
# -18401585 8
# -3852177 8
# -22595305 8
# -21374668 8
# -22226632 8
# -11150967 8
# -10233295 8
# -9446851 8
# -20391319 8
# -21374342 8
# -15934853 8
# -11674855 8
# -11281402 8
# -20259689 8
# -18293494 8
# -1188339 8
# -21111276 8
# -8200535 8
# -9445623 8
# -6168812 8
# -1187999 8
# -20848769 8
# -5251183 8
# -9379944 8
# -7151336 8
# -24452823 8
# -946020046 8
# -1187473 8
# -21372554 8
# -2236023 8
# -11279936 8
# -18292280 8
# -24059261 8
# -18291918 8
# -21371948 8
# -24386573 8
# -4004566 8
# -11082413 8
# -17635844 8
# -9902367 8
# -948050179 8
# -948050161 8
# -1186021 8
# -24058075 8
# -948050081 8
# -22681748 8
# -948050063 8
# -8460380 8
# -20715560 8
# -24057845 8
# -21436325 8
# -661300 8
# -15865643 8
# -22681130 8
# -22680924 8
# -22811979 8
# -14685354 8
# -9442423 8
# -9376700 8
# -22680470 8
# -21762876 8
# -9769786 8
# -22680340 8
# -23990815 8
# -23269620 8
# -6688983 8
# -21303341 8
# -23990315 8
# -2297880 8
# -23990253 8
# -20451300 8
# -14946166 8
# -21303089 8
# -266007 8
# -17764105 8
# -265991 8
# -11210486 8
# -14945790 8
# -17763801 8
# -11341019 8
# -11209862 8
# -11209786 8
# -23989301 8
# -12586001 8
# -23989041 8
# -22678314 8
# -23989021 8
# -22678200 8
# -17762833 8
# -23333268 8
# -17762483 8
# -24578129 8
# -24578113 8
# -17762317 8
# -3999748 8
# -20318208 8
# -17762301 8
# -14747412 8
# -15861511 8
# -19859108 8
# -17761783 8
# -11339247 8
# -13632919 8
# -17761573 8
# -9503922 8
# -17171606 8
# -22676598 8
# -8913909 8
# -17040301 8
# -10683112 8
# -11338365 8
# -5308770 8
# -942080032 8

# %% [markdown]
# From the list, we choose a random network that has only 8 channel segments, -20427622.
# If we examine the original dataframe, we can learn the lat-lon coordinates of our segment...

# %%
segment = -20427622
print(segment, len(independent_networks[segment]))

print(
    df.loc[-segment]
)  # remember, we need the -segment because we've labeled the tailwaters with a dummy downstream terminal value
# Out:
# -20427622 8
# to                -20427622
# gages    b'               '
# lat               33.045074
# lon             -112.275116
# Name: 20427622, dtype: object

# %% [markdown]
# ... and plot it's position on a map:

# %%
'''from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

_df = df.loc[[-segment]]
_geometry = [Point(xy) for xy in zip(_df["lon"], _df["lat"])]
_gdf = GeoDataFrame(_df, geometry=_geometry)

world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
_gdf.plot(ax=world.plot(figsize=(10, 6)), marker="o", color="red", markersize=15)'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 9
#       6 _geometry = [Point(xy) for xy in zip(_df["lon"], _df["lat"])]
#       7 _gdf = GeoDataFrame(_df, geometry=_geometry)
# ----> 9 world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
#      10 _gdf.plot(ax=world.plot(figsize=(10, 6)), marker="o", color="red", markersize=15)
#
# File ~/nwm_network_lstm_test/.venv/lib/python3.12/site-packages/geopandas/datasets/__init__.py:18, in get_path(dataset)
#      12 error_msg = (
#      13     "The geopandas.dataset has been deprecated and was removed in GeoPandas "
#      14     f"1.0. You can get the original '{dataset}' data from "
#      15     f"{ne_message if 'natural' in dataset else nybb_message}"
#      16 )
#      17 if dataset in _prev_available:
# ---> 18     raise AttributeError(error_msg)
#      19 else:
#      20     error_msg = (
#      21         "The geopandas.dataset has been deprecated and "
#      22         "was removed in GeoPandas 1.0. New sample datasets are now available "
#      23         "in the geodatasets package (https://geodatasets.readthedocs.io/en/latest/)"
#      24     )
#
# AttributeError: The geopandas.dataset has been deprecated and was removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.

# %% [markdown]
# Or, we can use a slightly more sophisticated map to discover that we have chosen an interior basin near Phoenix.

# %%
import folium

# create a map
this_map = folium.Map(prefer_canvas=True)


def plotDot(point):
    """input: series that contains a numeric named latitude and a numeric named longitude
    this function creates a CircleMarker and adds it to your this_map"""
    folium.CircleMarker(location=[point.lat, point.lon], radius=8, weight=5).add_to(
        this_map
    )


# use df.apply(,axis=1) to "iterate" through every row in your dataframe
_df.apply(plotDot, axis=1)


# Set the zoom to the maximum possible
this_map.fit_bounds(this_map.get_bounds())

# Save the map to an HTML file
this_map.save("simple_dot_plot.html")

this_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02e70da3773fdd13f3f330657e01785e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02e70da3773fdd13f3f330657e01785e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02e70da3773fdd13f3f330657e01785e = L.map(
#                 &quot;map_02e70da3773fdd13f3f330657e01785e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a0799a161d8f386b1b996aafc89e434 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a0799a161d8f386b1b996aafc89e434.addTo(map_02e70da3773fdd13f3f330657e01785e);
#
#
#             var circle_marker_7eeaf2a350ef83c04cb918a55020de78 = L.circleMarker(
#                 [33.045074462890625, -112.27511596679688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_02e70da3773fdd13f3f330657e01785e);
#
#
#             map_02e70da3773fdd13f3f330657e01785e.fitBounds(
#                 [[33.045074462890625, -112.27511596679688], [33.045074462890625, -112.27511596679688]],
#                 {}
#             );
#
#
#             tile_layer_0a0799a161d8f386b1b996aafc89e434.addTo(map_02e70da3773fdd13f3f330657e01785e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# So with that context for our tiny little drainage, we look at the connections and rconn dictionary results.

# %%
print(f"{connections[-segment]} the last item in the DAG points to our tailwater")
print(
    f"{rconn[segment]} ... and the upstream looking connection from the tailwater points to the last element of the DAG"
)
# Out:
# [-20427622] the last item in the DAG points to our tailwater
# [20427622] ... and the upstream looking connection from the tailwater points to the last element of the DAG

# %% [markdown]
# The `independent_networks` dictionary will show us which are the 8 segments in the DAG, each with their corresponding upstream neighbor or neighbors, which looks like the following for our example ...
#
# ```
# independent_networks[segment]
# {20427706: [20429532],
#  20429540: [],
#  20427622: [20427704, 20427706],
#  20429612: [],
#  20429616: [],
#  20427704: [20429540],
#  -20427622: [20427622],
#  20429532: [20429612, 20429616]}
#  ```

# %%
print(segment)
independent_networks[segment]
# Out:
# -20427622
# {20427706: [20429532],
#  20429540: [],
#  20427622: [20427704, 20427706],
#  20429612: [],
#  20429616: [],
#  20427704: [20429540],
#  -20427622: [20427622],
#  20429532: [20429612, 20429616]}

# %% [markdown]
# ... and the `reaches_bytw` object gives the order of these in reaches between junctions using DFS ordering only reveresed, to start at the leaves.
#
# for our example, this looks like
# ```
# reaches_bytw[-20427622]
#
# [[20429540, 20427704],
#  [20429612],
#  [20429616],
#  [20429532, 20427706],
#  [20427622, -20427622]]
#
# ```

# %%
print(segment)
reaches_bytw[segment]
# Out:
# -20427622
# [[20429540, 20427704],
#  [20429612],
#  [20429616],
#  [20429532, 20427706],
#  [20427622, -20427622]]

# %% [markdown]
# You'll have to look at this for a minute, but trust me, you can derive the following topological
# map from those two pieces of information. (Technically, you would only need the `independent_networks`
# information, but it's nice to get confirmation from the other object.)
# ```
# upstream...
#
#              20429612     20429616
#                  ├────────────┘
#  20429540    20429532
#     │            │
#  20427704    20427706
#     ├────────────┘
#  20427622
#     │
# -20427622
#
# downstream...
# ```

# %% [markdown]
# We can chain the segment IDs together -- this can be useful for instance if we want to query all IDs in a given basin.

# %%
from itertools import chain

list(chain(*reaches_bytw[segment]))
# Out:
# [20429540,
#  20427704,
#  20429612,
#  20429616,
#  20429532,
#  20427706,
#  20427622,
#  -20427622]
